# %% [markdown]
# # [Data 198] Assignment 0 - Git Activity

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
drivers = pd.read_csv("drivers.csv")
drivers
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
# 854       856         de_vries     45  DEV      Nyck    de Vries  1995-02-06
#
# ...

# %%
nationality = drivers['nationality'].value_counts()
nationality.plot.bar()

plt.xticks(fontsize=8)
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.title('Nationality Counts')
# Out:
# Text(0.5, 1.0, 'Nationality Counts')

# %%
drivers.tail(5)
# Out:
#      driverId        driverRef number code forename     surname         dob  \
# 850       852          tsunoda     22  TSU     Yuki     Tsunoda  2000-05-11
# 851       853          mazepin      9  MAZ   Nikita     Mazepin  1999-03-02
# 852       854  mick_schumacher     47  MSC     Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO   Guanyu        Zhou  1999-05-30
# 854       856         de_vries     45  DEV     Nyck    de Vries  1995-02-06
#
#     nationality                                           url
# 850    Japanese     http://en.wikipedia.org/wiki/Yuki_Tsunoda
# 851     Russian   http://en.wikipedia.org/wiki/Nikita_Mazepin
# 852      German  http://en.wikipedia.org/wiki/Mick_Schumacher
# 853     Chinese      http://en.wikipedia.org/wiki/Guanyu_Zhou
# 854       Dutch    http://en.wikipedia.org/wiki/Nyck_de_Vries

# %%
drivers.columns
# Out:
# Index(['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob',
#        'nationality', 'url'],
#       dtype='object')

# %%
drivers.drop(["driverId"], axis = 1)
# Out:
#            driverRef number code  forename     surname         dob  \
# 0           hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2            rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3             alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..               ...    ...  ...       ...         ...         ...
# 850          tsunoda     22  TSU      Yuki     Tsunoda  2000-05-11
# 851          mazepin      9  MAZ    Nikita     Mazepin  1999-03-02
# 852  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
# 854         de_vries     45  DEV      Nyck    de Vries  1995-02-06
#
#     nationality                                             url
# 0       British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# ...
